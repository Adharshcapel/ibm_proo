# %%
#model developemnt libraries and preprocessing libraries
import pandas  as pd
import numpy as np
from sklearn import preprocessing
import pygal
from IPython.display import SVG, display
import seaborn as sns

# %%
final_dataset= pd.read_csv('data/final_dataframe.csv')

# %%
final_dataset.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               1       1102           2                 1
# 1   49          0               2        279           1                 8
# 2   37          1               1       1373           1                 2
# 3   33          0               2       1392           1                 3
# 4   27          0               1        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               2              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
final_dataset.shape
# Out:
# (1470, 35)
